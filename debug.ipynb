# %%
from miditoolkit.midi import parser
import mido

# %%
path_midi = 'test_midis/test_1.mid'
midi_data = parser.MidiFile(path_midi)

# %%
midi_data.markers
# Out:
# [Marker(text="Marker ##", time=3840),
#  Marker(text="Marker ##", time=11520),
#  Marker(text="Marker ##", time=19200),
#  Marker(text="Marker ##", time=26880),
#  Marker(text="Marker ##", time=34560),
#  Marker(text="Marker ##", time=42240),
#  Marker(text="Marker ##", time=49920),
#  Marker(text="Marker ##", time=57600),
#  Marker(text="Marker ##", time=65280),
#  Marker(text="Marker ##", time=72960),
#  Marker(text="Marker ##", time=80640),
#  Marker(text="Marker ##", time=88320),
#  Marker(text="Marker ##", time=96000),
#  Marker(text="Marker ##", time=103680),
#  Marker(text="Marker ##", time=111360),
#  Marker(text="Marker ##", time=119040),
#  Marker(text="Marker ##", time=126720),
#  Marker(text="Marker ##", time=134400),
#  Marker(text="Marker ##", time=142080),
#  Marker(text="Marker ##", time=149760),
#  Marker(text="Marker ##", time=157440),
#  Marker(text="Marker ##", time=165120),
#  Marker(text="Marker ##", time=172800),
#  Marker(text="Marker ##", time=180480),
# ...

# %%
mido_data = mido.MidiFile(path_midi)

# %%
for m in mido_data.tracks[0]:
    print(m)
# Out:
# <meta message time_signature numerator=4 denominator=4 clocks_per_click=24 notated_32nd_notes_per_beat=8 time=0>
# <meta message key_signature key='G' time=0>
# <meta message smpte_offset frame_rate=24 hours=32 minutes=0 seconds=0 frames=0 sub_frames=0 time=0>
# <meta message set_tempo tempo=508475 time=0>
# <meta message marker text='Marker ##' time=3840>
# <meta message marker text='Marker ##' time=7680>
# <meta message marker text='Marker ##' time=7680>
# <meta message marker text='Marker ##' time=7680>
# <meta message marker text='Marker ##' time=7680>
# <meta message marker text='Marker ##' time=7680>
# <meta message marker text='Marker ##' time=7680>
# <meta message marker text='Marker ##' time=7680>
# <meta message marker text='Marker ##' time=7680>
# <meta message marker text='Marker ##' time=7680>
# <meta message marker text='Marker ##' time=7680>
# <meta message marker text='Marker ##' time=7680>
# <meta message marker text='Marker ##' time=7680>
# ...

# %%
for m in mido_data.tracks[1]:
    print(m)
# Out:
# <meta message track_name name='0_M' time=0>
# program_change channel=0 program=57 time=0
# control_change channel=0 control=7 value=127 time=0
# control_change channel=0 control=10 value=88 time=0
# control_change channel=0 control=121 value=0 time=0
# control_change channel=0 control=123 value=0 time=40
# control_change channel=0 control=93 value=65 time=40
# control_change channel=0 control=91 value=100 time=40
# control_change channel=0 control=64 value=0 time=40
# note_on channel=0 note=72 velocity=123 time=16400
# note_on channel=0 note=72 velocity=0 time=384
# note_on channel=0 note=69 velocity=114 time=96
# note_on channel=0 note=69 velocity=0 time=192
# note_on channel=0 note=69 velocity=113 time=48
# note_on channel=0 note=69 velocity=0 time=460
# note_on channel=0 note=66 velocity=106 time=740
# note_on channel=0 note=66 velocity=0 time=192
# note_on channel=0 note=69 velocity=106 time=48
# note_on channel=0 note=69 velocity=0 time=192
# ...
